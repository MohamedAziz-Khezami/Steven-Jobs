# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
ln = pd.read_csv('linkedin_jobs_27072024.csv')

# %%
len(ln.job_description)
# Out:
# 267

# %% [markdown]
# ## **Skills extraction**

# %%
import google.generativeai as genai


genai.configure(api_key="AIzaSyAX5hRxjQ64IqZxqNcdj7ONpALMWxnIHb0")

model = genai.GenerativeModel('gemini-1.5-flash')

# %%
prompt_empy = '{"key_words":[]}'

prompt = '''
Read the following job description and return key words of all the skills required for this job.



No explanations, uniques keywords, no duplicates, Be breif.


'''

# %%
def skills_extraction(job_desc):

    
    if job_desc == "":
        prompt_id = prompt_empy
    else:
        prompt_id = prompt + job_desc
    output = model.generate_content(prompt_id)

    
    return output.candidates[0].content.parts[0].text.strip().replace("-","").split('\n')

# %% [markdown]
# ## Linkedin Skills

# %%
import pandas as pd
import numpy as np

# Sample DataFrame

df_ln = ln.job_description

# Divide into 12 batches
batch_size = len(df_ln) // 12
batches = np.array_split(df_ln, batch_size)

# Access individual batches
batchs = [batches[0], batches[1], batches[2], batches[3], batches[4], batches[5], batches[6], batches[7], batches[8], batches[9], batches[10], batches[11]]
# Out:
# c:\Users\nki\Documents\Steven Jobs\venv\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
bat = []

for i in batchs:
    b= ""
    for j in i:
        b = b + j
    bat.append(b)

# %%
bat
# Out:
# ["Na Sport Zone estamos empenhados em criar e manter um ambiente fundamentado na cooperação e no respeito mútuo, com um compromisso sólido com a Diversidade e a Igualdade de oportunidades. Reconhecemos e valorizamos todas as pessoas, independentemente da sua identidade de género, orientação sexual, etnia, religião, idade ou condição física.Os nossos processos de seleção são conduzidos com base numa avaliação de competências, onde priorizamos a paixão, a vontade de aprender e o desejo de crescer num ambiente internacional.Procuramos jovens com uma atitude positiva, apaixonados pelo atendimento ao público, mesmo em ambientes de trabalho com ritmo acelerado. Valorizamos aqueles que encaram os desafios com entusiasmo, que os veem como oportunidades de desenvolvimento, crescimento profissional e aprendizagem de novas competências. É também essencial possuir uma excelente capacidade de comunicação e habilidade para trabalhar em equipa.No teu dia a dia, como Sales Assistant, irás:Garantir uma experiência excecional ao cliente, oferecendo um serviço de excelência;Manter-te atualizado/a sobre os produtos mais modernos e exclusivos, assegurando os padrões de vendas estabelecidos;Trabalhar com a tua equipa para alcançar objetivos de vendas e os indicadores-chave de performance (KPIs), mantendo-te informado/a sobre as tendências atuais, as promoções em loja e os processos em constante evolução.Requisitos:12º ano de escolaridade, curso técnico com a mesma equivalência ou ensino superior;Excelência no atendimento ao cliente;Boa capacidade de comunicação;Flexibilidade horária;Paixão pelo calçado e pelo ramo retalho/moda. O que temos para te oferecer:Integração num grupo multinacional;Desconto exclusivo para colaboradores e outros benefícios;Remuneração base, complementada por bónus variáveis, alinhados com os objetivos de vendas alcançados;Horários flexíveis, compatíveis com os teus estudos e necessidades pessoais;Oportunidade de formação contínua, para que possas expandir os teus conhecimentos e habilidades ao longo do tempo.Queremos conhecer-te! Se acreditas que esta oferta é ideal para ti, inscreve-te já! Avaliaremos todas as candidaturas que preencham os requisitos e entraremos em contacto para agendar uma entrevista.
both the International Baccalaureate and local educational systems.About Oxbridge International SchoolWe have 200+ employees so far working with us and 50+ of them are expats. There's a firm dedication to continually train all staff members and offer leadership development opportunities across all levels. You can discover videos of the school on YouTube to gain insight into its facilities, team, and overall atmosphere. It's a fantastic chance to save money since the cost of living in Tashkent is affordable.Youtube ChannelInstagramFacebookVery competitive package is provided.Main duties and responsibilities of the job:Collaboratively planning, preparing and delivering differentiated lessonsAssessing and reporting student progressResponsible for student welfare and pastoral development of the class groupMaintaining the learning environment of the classroom and managing resourcesOrganizing and taking part in school events, trips, and extra-curricular activitiesLine management of the teaching assistantThe ideal candidate will have:At least Bachelor's degreePrevious experienceThe ability to differentiate and deliver conceptual, engaging and inquiry-based lessonsFamiliarity and experience with collaborative planning and a team-teaching approachA wonderful opportunity to discover Central Asia and work in one of the most dynamic schools of Tashkent, Uzbekistan. We have over 250 people working together to provide high quality education to the students and over 40 expats.Please note that the job requires relocation!Powered by JazzHRBVT ...
#  'Missions : sous l’autorité hiérarchique du Responsable Maintenance Site, vous serez chargé de :1- Maintenir l\'ensemble du matériel de l\'entreprise ainsi que les installations d\'infrastructure par des actions préventives et curatives.2-Maintenir de la mise en conformité des dispositifs de sécurité3-Respecter les règles de sécurité existantes4-Superviser du bâtiment et des énergies avec transmission des problématiques aux responsables.De formation initiale : BTS ou BTP en maintenance ou électricité industrielle avec une expérience de 1 à 3 ans dans une fonction équivalente, maitrise de la langue française, avoir de la rigueur , une bonne communication et un esprit d’équipe.Le poste est situé à fouchena ZI MGHIRA 3.Il s’agit d’un poste en plein temps avec un contrat à durée déterminée et une équipe de 8 personnes au sein du service maintenance.Si vous vous reconnaissez dans cette annonce, que vous souhaitez évoluer au sein d’un groupe en plein développement et que vous êtes une personne de challenge... n\'hésitez plus, envoyez-nous votre candidature !An exciting opportunity to work within a vibrant and dynamic International School in Tashkent, Uzbekistan, which boasts both the International Baccalaureate and local educational systems.About Oxbridge International SchoolWe have 200+ employees so far working with us and 50+ of them are expats. There\'s a firm dedication to continually train all staff members and offer leadership development opportunities across all levels. You can discover videos of the school on YouTube to gain insight into its facilities, team, and overall atmosphere. It\'s a fantastic chance to save money since the cost of living in Tashkent is affordable.Youtube ChannelInstagramFacebookVery competitive package is provided.Main duties and responsibilities of the job:Collaboratively planning, preparing and delivering differentiated lessonsAssessing and reporting student progressResponsible for student welfare and pastoral development of the class groupMaintaining the learning environment of the classroom and managing resourcesOrganizing and taking part in school events, trips, and extra-curricular activitiesLine management of the teaching assistantThe ideal candidate will have:At least Bachelor\'s degreePrevious experienceThe ability to differentiate and deliver conceptual, engaging and inquiry-based lessonsFamiliarity and experience with collaborative planning and a team-teaching approachA wonderful opportunity to discover Central Asia and work in one of the most dynamic schools of Tashkent, Uzbekistan. We have over 250 people working together to provide high quality education to the students and over 40 expats.Please note that the job requires relocation!Powered by JazzHRyHa9zM5kO4If you\'re a professional who works with text, we have an exciting opportunity to use your writing, editing, technical, and creative skills in a new and innovative way. As an AI Tutor - Writer, you won\'t just be writing; you\'ll be helping to shape the future of AI.We\'re seeking freelance writers, copywriters, and wordsmiths to collaborate with us in creating a diverse range of content. This role is more than traditional copywriting; it involves training AI systems by crafting text that teaches and informs their responses.As an AI Tutor - Writer you will use your writing skills to create text on a wide range of topics. Working within our style guide, you will create responses that will form the ‘voice\' for future AI. You will create original, helpful, honest, harmless text responses and you\'ll fact check your work using verifiable sources.RequirementsYou have some professional or educational experience in creative writing, copywriting or editing in ArabicYour level of Arabic is native or proficiency (C2)Your level of English is upper-intermediate (B2) or aboveYou have a degree in communications, linguistics, literature, journalism, or similarYou are ready to learn new methods, able to switch between projects and topics quickly ...
#  'If you\'re a professional who works with text, we have an exciting opportunity to use your writing, editing, technical, and creative skills in a new and innovative way. As an AI Tutor - Writer, you won\'t just be writing; you\'ll be helping to shape the future of AI.We\'re seeking freelance writers, copywriters, and wordsmiths to collaborate with us in creating a diverse range of content. This role is more than traditional copywriting; it involves training AI systems by crafting text that teaches and informs their responses.As an AI Tutor - Writer you will use your writing skills to create text on a wide range of topics. Working within our style guide, you will create responses that will form the ‘voice\' for future AI. You will create original, helpful, honest, harmless text responses and you\'ll fact check your work using verifiable sources.RequirementsYou have some professional or educational experience in creative writing, copywriting or editing in ArabicYour level of Arabic is native or proficiency (C2)Your level of English is upper-intermediate (B2) or aboveYou have a degree in communications, linguistics, literature, journalism, or similarYou are ready to learn new methods, able to switch between projects and topics quickly and sometimes work with challenging, complex guidelinesOur freelance role is fully remote so, you just need a laptop, internet connection, time available and enthusiasm to take on a challengeBenefitsTake part in part-time, remote, freelance projects that respect your primary professional or academic commitmentsTry your hand at an AI project and enrich your portfolio with new experiencesMake a tangible impact on the quality of AIIf you\'re a professional who works with text, we have an exciting opportunity to use your writing, editing, technical, and creative skills in a new and innovative way. As an AI Tutor - Writer, you won\'t just be writing; you\'ll be helping to shape the future of AI.We\'re seeking freelance writers, copywriters, and wordsmiths to collaborate with us in creating a diverse range of content. This role is more than traditional copywriting; it involves training AI systems by crafting text that teaches and informs their responses.As an AI Tutor - Writer you will use your writing skills to create text on a wide range of topics. Working within our style guide, you will create responses that will form the ‘voice\' for future AI. You will create original, helpful, honest, harmless text responses and you\'ll fact check your work using verifiable sources.RequirementsYou have some professional or educational experience in creative writing, copywriting or editing in ArabicYour level of Arabic is native or proficiency (C2)Your level of English is upper-intermediate (B2) or aboveYou have a degree in communications, linguistics, literature, journalism, or similarYou are ready to learn new methods, able to switch between projects and topics quickly and sometimes work with challenging, complex guidelinesOur freelance role is fully remote so, you just need a laptop, internet connection, time available and enthusiasm to take on a challengeBenefitsTake part in part-time, remote, freelance projects that respect your primary professional or academic commitmentsTry your hand at an AI project and enrich your portfolio with new experiencesMake a tangible impact on the quality of AIIf you\'re a professional who works with text, we have an exciting opportunity to use your writing, editing, technical, and creative skills in a new and innovative way. As an AI Tutor - Writer, you won\'t just be writing; you\'ll be helping to shape the future of AI.We\'re seeking freelance writers, copywriters, and wordsmiths to collaborate with us in creating a diverse range of content. This role is more than traditional copywriting; it involves training AI systems by crafting text that teaches and informs their responses.As an AI Tutor - Writer you will use your writing skills to create text on a wide range of topics. Wor ...
#  "If you're a professional who works with text, we have an exciting opportunity to use your writing, editing, technical, and creative skills in a new and innovative way. As an AI Tutor - Writer, you won't just be writing; you'll be helping to shape the future of AI.We're seeking freelance writers, copywriters, and wordsmiths to collaborate with us in creating a diverse range of content. This role is more than traditional copywriting; it involves training AI systems by crafting text that teaches and informs their responses.As an AI Tutor - Writer you will use your writing skills to create text on a wide range of topics. Working within our style guide, you will create responses that will form the ‘voice' for future AI. You will create original, helpful, honest, harmless text responses and you'll fact check your work using verifiable sources.RequirementsYou have some professional or educational experience in creative writing, copywriting or editing in FrenchYour level of French is native or proficiency (C2)Your level of English is upper-intermediate (B2) or aboveYou have a degree in communications, linguistics, literature, journalism, or similarYou are ready to learn new methods, able to switch between projects and topics quickly and sometimes work with challenging, complex guidelinesOur freelance role is fully remote so, you just need a laptop, internet connection, time available and enthusiasm to take on a challengeBenefitsTake part in part-time, remote, freelance projects that respect your primary professional or academic commitmentsTry your hand at an AI project and enrich your portfolio with new experiencesMake a tangible impact on the quality of AIVidal Associates Consulting and Search, acteur de référence dans le recrutement par approche directe de cadres spécialistes et de dirigeants en France et à l'international, recrute pour son client un(e) PMO , poste basé à Tunis (Tunisie) .Nous recrutons pour notre client un éditeur de logiciel un(e) :PMO H/FPoste basé à Tunis (Tunisie)Rattaché à la Direction des Opérations de Production Cloud, vous aurez comme missions de : Participer à la mise en place de la gouvernance des projets ; Piloter le suivi du projet et la mise en œuvre des actions de la feuille de route et ajustement : planning, pilotage du chemin critique, maintien à jour des tableaux de bord ; Communiquer avec les parties prenantes et agir sur la gouvernance projet mise en place pour l'atteinte des objectifs projet ; Synchroniser l'ensemble des activités : suivi des incidents, des décalages et des besoins de replanification ; Identifier les risques, les solutions de mitigation durant tout le projet et lever les alertes potentielles ; Organiser et sécuriser la phase de transfert des projets (Build to RUN) vers les équipes Opérations.De formation ingénieur .Vous disposez d'une expérience significative dans les systéme d'informations et la gestion des projets.Vous etes axés sur la démarche, l'efficacité et capable de mettre en place un cadre (KPI, objectifs, roadmap) de le suivre et de le faire respecter par les équipes.Vous avez une bonne capacité de communication, à l'oral comme à l'écrit en Français et en Anglais.Engagement, initiative, organisation, méthodologie et gestion des conflits ,gestion efficace des escalades , excellente communication et compétence pédagogique ,sont vos atouts pour réussir ce poste.Afin d'étudier votre candidature avec attention, nous vous remercions de l'adresser à VIDAL ASSOCIATES Consulting & Search, en déposant votre dossier sous la référence « Ve15303F » sur notre site www.talentup.com ou par email à ve15303f-145@talentup.netJob descriptionFaculty Positions in Artificial Intelligence, Management, English, and Applied MathematicsInstitution: Pristini School of AILocation: Novation City, Sousse, TunisiaType: Full-TimeStart Date: August 2024Application deadline: OpenAbout Pristini School of AI:Pristini School of AI is a pioneering university in the field of Artificial Intelligence having  ...
de laboratoire est rattaché hiérarchiquement, au responsable direct qui lui attribue les tâches à effectuer en fonction des impératifs du service.Il assure la réalisation des analyses physico-chimiques et microbiologiquesEffectuer les analyses physico-chimiques selon des techniques en vigueur validées, en observant les règles de Bonnes Pratiques de Laboratoire BPL, ainsi que les règles d’hygiène, de santé et de protection de l’environnement (HSE), y afférentes.Responsable des équipements et ou des taches qui lui sont attribuées selon le planning de domaine de responsabilité Doit veiller à l’ordre et à aux rangements des réactifs, de la verrerie et des différents accessoires des appareils du laboratoire ainsi que les déchets des solvantsDoit signaler toute anomalie ou déviation observée lors des manipulationsParticipe à la gestion des stocks des substances de référence, étalons, solvants et réactifs et signaler la nécessité de commande des pièces de rechange, verrerie, colonne et autres consommablesDoit participer à la propreté du laboratoire et Participe à la réception des échantillons pour le contrôle et à la destruction de ces derniersPursue progress, discover extraordinaryBetter is out there. Better medications, better outcomes, better science. But progress doesn’t happen without people – people from different backgrounds, in different locations, doing different roles, all united by one thing: a desire to make miracles happen. So, let’s be those people.At Sanofi, we provide equal opportunities to all regardless of race, colour, ancestry, religion, sex, national origin, sexual orientation, age, citizenship, marital status, ability or gender identity.Watch our ALL IN video and check out our Diversity Equity and Inclusion actions at sanofi.com!Nous recherchons activement des commerciaux ayant une maîtrise de l'allemand pour rejoindre notre équipe. Vous serez chargé(e) de :Engager avec les clients germanophones pour comprendre leurs besoins et objectifs commerciaux.Développer et exécuter des stratégies de vente efficaces pour élargir notre présence sur le marché.Établir et maintenir des relations solides avec les clients en agissant en tant que conseiller de confiance.Collaborer étroitement avec les équipes internes pour garantir un service client optimal et promouvoir l'innovation continue.Avantages :Opportunité de contribuer activement à la croissance de l'entreprise.Développement professionnel dans un environnement dynamique et collaboratif.Possibilité d'acquérir et d'améliorer des compétences en vente et en gestion de relations clients.Compétences Requises :Maîtrise de l'allemand à l'écrit et à l'oral.Excellentes compétences en communication et en relations interpersonnelles.Fortes capacités de négociation et résolution de problèmes, orientées vers les résultats.Capacité à travailler de manière autonome et en équipe dans un environnement dynamique.Préférence pour une  ...

# %%
len(bat)
# Out:
# 12

# %%
import time
ln_skills = []

for i in tqdm(bat, desc="Extracting skills"):
    s = skills_extraction(i)
    ln_skills.append(s)
# Out:
# Extracting skills: 100%|██████████| 12/12 [00:46<00:00,  3.89s/it]

# %%
ls = []
for i in ln_skills:
    for j in i:
        ls.append(j)
# Out:
# 689

# %%
linkedin_skills = pd.DataFrame(ls, columns=['skills'])

# %%
linkedin_skills.to_csv('linkedin_skills.csv', index=False)

# %% [markdown]
# ## Bayt skills

# %%
bayt = pd.read_csv('bayt_jobs_27072024.csv')

# %%
bayt.head(3)
# Out:
#   post_date                                         job_title  \
# 0   2024-07   Goldstar / Inside Sales Representative - French
# 1   2024-07                                  Senior Recruiter
# 2   2024-07  Research Associate - Rangeland Landscape Ecology
#
#                                      job_description  \
# 0  Job Title:  Goldstar Inside Sales Representati...
# 1  Location: Tunis, TN, 1053 Senior RecruiterThe ...
# 2  Research Associate - Rangeland Landscape Ecolo...
#
#                         company        location  \
# 0                  National Pen  Tunis, Tunisia
# 1                    Vistaprint  Tunis, Tunisia
# 2  CGIAR System Reference Group         Tunisia
#
#                           industry
# 0  Other Business Support Services
# 1  Other Business Support Services
# 2  Other Business Support Services

# %%
df_bayt = bayt.job_description

# Divide into 12 batches
batch_size = len(df_bayt) // 12
batches = np.array_split(df_bayt, batch_size)

# Access individual batches
batchs = [batches[0], batches[1], batches[2], batches[3], batches[4], batches[5], batches[6], batches[7], batches[8], batches[9], batches[10], batches[11]]
# Out:
# c:\Users\nki\Documents\Steven Jobs\venv\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
batchs
# Out:
# [0     Job Title:  Goldstar Inside Sales Representati...
#  1     Location: Tunis, TN, 1053 Senior RecruiterThe ...
#  2     Research Associate - Rangeland Landscape Ecolo...
#  3     regulatory Affairs Coordinator-Fresh Graduated...
#  4     Sales representative page is loaded Sales repr...
#  5     Job Number 24131589 Job Category Food and Beve...
#  6     Acronis is a world leader in cyber protection—...
#  7     Systems Engineer                              ...
#  8     Job Number 24131599 Job Category Event Managem...
#  9     About Four Seasons:Four Seasons is powered by ...
#  10    LEONI is a global provider of products, soluti...
#  11    Assistant stewarding manager page is loaded As...
#  Name: job_description, dtype: object,
#  12    Job Description:At Ferring Pharmaceuticals, we...
#  13    Job Title:  Merchandising Coordinator, Apparel...
#  14    Oferta de trabajo:  Inbound Customer Care Agen...
#  15    Job Title:   Transactional Agent - Spanish  Lo...
#  16    JOB DESCRIPTION:Abbott is a global healthcare ...
#  17    An exciting opportunity to work within a vibra...
#  18    HR Business PartnerLocation -Tunis , ,Tunisia ...
#  19    Description de l'entreprisePourquoi travailler...
#  20    About Four Seasons:Four Seasons is powered by ...
#  21    An exciting opportunity to work within a vibra...
#  22    Reports to: Team Leader Rangeland Ecology & Fo...
#  23    Summary:The MEL Officer plays a crucial role i...
#  Name: job_description, dtype: object,
#  24    Graphic Designer Temps completDescription de l...
#  25    Titolo di lavoro: Agente di vendita web inboun...
#  26    Job Title: Service Request Coordinator  Report...
#  27    Reports to: Team Leader Rangeland Ecology & Fo...
#  28    Description de l'entrepriseLe Groupe LACROIX (...
#  29    Job Number 24130291 Job Category Human Resourc...
#  30    An exciting opportunity to work within a vibra...
#  31    An exciting opportunity to work within a vibra...
#  32    Description de l'entreprisePourquoi travailler...
#  33    Nous recherchons sur notre site de M'Hamdia (B...
#  34    An exciting opportunity to work within a vibra...
#  35    What we are looking for: A highly driven and s...
#  Name: job_description, dtype: object,
#  36    Job DescriptionPiloter le recrutement et l'int...
#  37    Public Health Officer (Health Promotion and De...
#  38    Operations Officer (PN458347) (CPCP) - ( 24060...
#  39    Service Delivery Manager with French page is l...
#  40    Health Emergency Officer (PN458345) (CPCP) - (...
#  41    Programme Management Officer (PN458346) (CPCP)...
#  42    Location -Tunis ,  ,Tunisia (TN) \nJob ID -647...
#  43    Graphic Designer Temps completDescription de l...
#  44    Pharmacien Responsable TechniqueLieu : Megrine...
#  45    The Data Creation Supervisor is responsible fo...
#  46    Senior DevOps EngineerDate: Jul 22, 2024 Locat...
#  47    Job Description - Expert Customs & Export Cont...
#  Name: job_description, dtype: object,
#  48    assisstant banqueting managerJOB\_DESCRIPTION....
#  49    Senior Data Scientist - Jumia (Full Time)at Ju...
#  50    Are you passionate about entrepreneurship and ...
#  51    Job DescriptionPiloter le processus d'industri...
#  52    Job Title:  Transactional Agent - Italian  Loc...
#  53    Job Summary• This role is responsible for over...
#  54    Are you passionate about entrepreneurship and ...
#  55    Job Description - TL Logistics Network Purchas...
#  56    Company DescriptionJobs for Humanity is collab...
#  57    Company DescriptionJobs for Humanity is collab...
#  58    Company DescriptionJobs for Humanity is collab...
#  59    Company DescriptionJobs for Humanity is collab...
#  Name: job_description, dtype: object,
#  60    Company DescriptionJobs for Humanity is collab...
#  61    Company DescriptionJobs for Humanity is collab...
#  62    Company DescriptionJobs for Humanity is collab...
#  63    Company DescriptionJobs for Humanity is collab...
#  64    Company DescriptionJobs for Humanity is collab...
#  65    See our Information Technology · Tunis Senior ...
#  66    Specialist, Prod Planning & ControlJoin Yazaki...
#  67    Systèmes de faisceaux de câbles modernes et in...
#  68    Company DescriptionJobs for Humanity is collab...
#  69    Company DescriptionJobs for Humanity is collab...
#  70    Company DescriptionJobs for Humanity is collab...
#  71    Company DescriptionJobs for Humanity is collab...
#  Name: job_description, dtype: object,
#  72    Company DescriptionJobs for Humanity is collab...
#  73    Systèmes de faisceaux de câbles modernes et in...
#  74    Company DescriptionJobs for Humanity is collab...
#  75    Chief concierge page is loaded Chief concierge...
#  76    Job DescriptionRépondre aux besoins des unités...
#  77    Bienvenue chez Treatwell, nice to meet you !No...
#  78    Job DescriptionPiloter le recrutement et l'int...
#  79    Job Title: Talent Acquisition ManagerReport to...
#  80    About Four Seasons:Four Seasons is powered by ...
#  81    Nous recherchons un Ingénieur RPA Medior expér...
#  82    Job Title:Conseiller client /Support Technique...
#  83    Description de l'entrepriseClassé dans le TOP ...
#  Name: job_description, dtype: object,
#  84    Nous recherchons un Ingénieur RPA Junior passi...
#  85    We are looking for a talented and motivated Em...
#  86    Join Yazaki. Connect to the future.  Country: ...
#  87    Team Leader, Industrial EngineeringJoin Yazaki...
#  88    Fonctions lis aux postes : Prparation de la ve...
#  89    About the job Software Project Manager Associa...
#  90    Description de l'entreprisePourquoi travailler...
#  91    Job ID -6467 Purpose Of the Job:Ensure excelle...
#  92    Job Role Junior Project Officer Compensation A...
#  93    Head of Ethics and Business Integrity Morocco/...
#  94    Description de l'entrepriseAccélérez votre car...
#  95    Company DescriptionAt Allergan Aesthetics, an ...
#  Name: job_description, dtype: object,
#  96     Head of Ethics and Business Integrity Morocco/...
#  97     This is where you save and sustain livesAt Bax...
#  98     The world of finance moves fast. At FIS, we’re...
#  99     We are FIS. Our technology powers the world’s ...
#  100    The Portfolio Director is a member of the Seni...
#  101    Job Role Project Officer Compensation Annual n...
#  102    Are you curious, motivated, and forward-thinki...
#  103    If you’re here, it’s because you’re looking fo...
#  104    About the team:Valdi is a suite of global mult...
#  105    Are you curious, motivated, and forward-thinki...
#  106    If you’re here, it’s because you’re looking fo...
#  107    Join Yazaki. Connect to the future.  Country: ...
#  Name: job_description, dtype: object,
#  108    We are FIS. Our technology powers the world’s ...
#  109    This position will work with FHI 360’s Middle ...
#  110    As Print Contractual Diagnostic Before Dispatc...
#  111    The CARE Operations Supervisor provides guidan...
#  112    Job Title:  HR Administration Officer - Traine...
#  113    Job Number 24124917 Job Category Sales & Marke...
#  114    Company DescriptionAbbVie's mission is to disc...
#  115    Inside Regional Account Manager Location: Tuni...
#  116    Job Description:SAP consultantJob DescriptionJ...
#  117    Systèmes de faisceaux de câbles modernes et in...
#  118    Job Description - Lead Expert Supplier Quality...
#  119    Vantive: A New Company Built On Our LegacyBaxt...
#  Name: job_description, dtype: object,
#  120                                                  NaN
#  121                                                  NaN
#  122                                                  NaN
#  123                                                  NaN
#  124                                                  NaN
#  125                                                  NaN
#  126                                                  NaN
#  127                                                  NaN
#  128                                                  NaN
#  129    Job DescriptionCartographier les processus de ...
#  130    An exciting opportunity to work within a vibra...
#  131    An exciting opportunity to work within a vibra...
#  Name: job_description, dtype: object,
#  132    Job Name: Tunisia - Asa:01 Pre-Shipment & Load...
#  133    Job SummaryYou will be responsible for selling...
#  134    Dans le cadre d’une monte en charge et renforc...
#  135    About Four Seasons:Four Seasons is powered by ...
#  136    An exciting opportunity to work within a vibra...
#  137    Job DescriptionEffectuer la maintenance curati...
#  138    Job DescriptionAssurer la disponibilité des mo...
#  139    Regulatory Affairs Officer 295004-placeholder ...
#  140    Systèmes de faisceaux de câbles modernes et in...
#  141    Job Title:  Financial Accountant  Location: Tu...
#  142    Description de l'entrepriseLe Groupe LACROIX (...
#  143    Vantive: A New Company Built On Our LegacyBaxt...
#  Name: job_description, dtype: object]

# %%
bat = []

for i in batchs:
    b= ""
    for j in str(i):
        b = b + j
    bat.append(b)

# %%
bat
# Out:
# ['0     Job Title:\xa0 Goldstar Inside Sales Representati...\n1     Location: Tunis, TN, 1053 Senior RecruiterThe ...\n2     Research Associate - Rangeland Landscape Ecolo...\n3     regulatory Affairs Coordinator-Fresh Graduated...\n4     Sales representative page is loaded Sales repr...\n5     Job Number 24131589 Job Category Food and Beve...\n6     Acronis is a world leader in cyber protection—...\n7     Systems Engineer \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0...\n8     Job Number 24131599 Job Category Event Managem...\n9     About Four Seasons:Four Seasons is powered by ...\n10    LEONI is a global provider of products, soluti...\n11    Assistant stewarding manager page is loaded As...\nName: job_description, dtype: object',
#  "12    Job Description:At Ferring Pharmaceuticals, we...\n13    Job Title: \xa0Merchandising Coordinator, Apparel...\n14    Oferta de trabajo: \xa0Inbound Customer Care Agen...\n15    Job Title: \xa0 Transactional Agent - Spanish  Lo...\n16    JOB DESCRIPTION:Abbott is a global healthcare ...\n17    An exciting opportunity to work within a vibra...\n18    HR Business PartnerLocation -Tunis , ,Tunisia ...\n19    Description de l'entreprisePourquoi travailler...\n20    About Four Seasons:Four Seasons is powered by ...\n21    An exciting opportunity to work within a vibra...\n22    Reports to: Team Leader Rangeland Ecology & Fo...\n23    Summary:The MEL Officer plays a crucial role i...\nName: job_description, dtype: object",
#  "24    Graphic Designer Temps completDescription de l...\n25    Titolo di lavoro: Agente di vendita web inboun...\n26    Job Title: Service Request Coordinator  Report...\n27    Reports to: Team Leader Rangeland Ecology & Fo...\n28    Description de l'entrepriseLe Groupe LACROIX (...\n29    Job Number 24130291 Job Category Human Resourc...\n30    An exciting opportunity to work within a vibra...\n31    An exciting opportunity to work within a vibra...\n32    Description de l'entreprisePourquoi travailler...\n33    Nous recherchons sur notre site de M'Hamdia (B...\n34    An exciting opportunity to work within a vibra...\n35    What we are looking for:\xa0A highly driven and s...\nName: job_description, dtype: object",
#  "36    Job DescriptionPiloter le recrutement et l'int...\n37    Public Health Officer (Health Promotion and De...\n38    Operations Officer (PN458347) (CPCP) - ( 24060...\n39    Service Delivery Manager with French page is l...\n40    Health Emergency Officer (PN458345) (CPCP) - (...\n41    Programme Management Officer (PN458346) (CPCP)...\n42    Location -Tunis\xa0,\xa0\xa0,Tunisia (TN)\xa0\\nJob ID -647...\n43    Graphic Designer Temps completDescription de l...\n44    Pharmacien Responsable TechniqueLieu\u202f:\xa0Megrine...\n45    The Data Creation Supervisor is responsible fo...\n46    Senior DevOps EngineerDate: Jul 22, 2024 Locat...\n47    Job Description - Expert Customs & Export Cont...\nName: job_description, dtype: object",
#  "48    assisstant banqueting managerJOB\\_DESCRIPTION....\n49    Senior Data Scientist - Jumia (Full Time)at Ju...\n50    Are you passionate about entrepreneurship and ...\n51    Job DescriptionPiloter le processus d'industri...\n52    Job Title:\xa0 Transactional Agent - Italian  Loc...\n53    Job Summary• This role is responsible for over...\n54    Are you passionate about entrepreneurship and ...\n55    Job Description - TL Logistics Network Purchas...\n56    Company DescriptionJobs for Humanity is collab...\n57    Company DescriptionJobs for Humanity is collab...\n58    Company DescriptionJobs for Humanity is collab...\n59    Company DescriptionJobs for Humanity is collab...\nName: job_description, dtype: object",
#  '60    Company DescriptionJobs for Humanity is collab...\n61    Company DescriptionJobs for Humanity is collab...\n62    Company DescriptionJobs for Humanity is collab...\n63    Company DescriptionJobs for Humanity is collab...\n64    Company DescriptionJobs for Humanity is collab...\n65    See our Information Technology · Tunis Senior ...\n66    Specialist, Prod Planning & ControlJoin Yazaki...\n67    Systèmes de faisceaux de câbles modernes et in...\n68    Company DescriptionJobs for Humanity is collab...\n69    Company DescriptionJobs for Humanity is collab...\n70    Company DescriptionJobs for Humanity is collab...\n71    Company DescriptionJobs for Humanity is collab...\nName: job_description, dtype: object',
#  "72    Company DescriptionJobs for Humanity is collab...\n73    Systèmes de faisceaux de câbles modernes et in...\n74    Company DescriptionJobs for Humanity is collab...\n75    Chief concierge page is loaded Chief concierge...\n76    Job DescriptionRépondre aux besoins des unités...\n77    Bienvenue chez Treatwell, nice to meet you !No...\n78    Job DescriptionPiloter le recrutement et l'int...\n79    Job Title: Talent Acquisition ManagerReport to...\n80    About Four Seasons:Four Seasons is powered by ...\n81    Nous recherchons un Ingénieur RPA Medior expér...\n82    Job Title:Conseiller client /Support Technique...\n83    Description de l'entrepriseClassé dans le TOP ...\nName: job_description, dtype: object",
#  "84    Nous recherchons un Ingénieur RPA Junior passi...\n85    We are looking for a talented and motivated Em...\n86    Join Yazaki. Connect to the future.\xa0 Country:\xa0...\n87    Team Leader, Industrial EngineeringJoin Yazaki...\n88    Fonctions lis aux postes :\xa0Prparation de la ve...\n89    About the job Software Project Manager Associa...\n90    Description de l'entreprisePourquoi travailler...\n91    Job ID -6467 Purpose Of the Job:Ensure excelle...\n92    Job Role Junior Project Officer Compensation A...\n93    Head of Ethics and Business Integrity Morocco/...\n94    Description de l'entrepriseAccélérez votre car...\n95    Company DescriptionAt Allergan Aesthetics, an ...\nName: job_description, dtype: object",
#  '96     Head of Ethics and Business Integrity Morocco/...\n97     This is where you save and sustain livesAt Bax...\n98     The world of finance moves fast. At FIS, we’re...\n99     We are FIS. Our technology powers the world’s ...\n100    The Portfolio Director is a member of the Seni...\n101    Job Role Project Officer Compensation Annual n...\n102    Are you curious, motivated, and forward-thinki...\n103    If you’re here, it’s because you’re looking fo...\n104    About the team:Valdi is a suite of global mult...\n105    Are you curious, motivated, and forward-thinki...\n106    If you’re here, it’s because you’re looking fo...\n107    Join Yazaki. Connect to the future.\xa0 Country:\xa0...\nName: job_description, dtype: object',
#  "108    We are FIS. Our technology powers the world’s ...\n109    This position will work with FHI 360’s Middle ...\n110    As Print Contractual Diagnostic Before Dispatc...\n111    The CARE Operations Supervisor provides guidan...\n112    Job Title: \xa0HR Administration Officer - Traine...\n113    Job Number 24124917 Job Category Sales & Marke...\n114    Company DescriptionAbbVie's mission is to disc...\n115    Inside Regional Account Manager\xa0Location: Tuni...\n116    Job Description:SAP consultantJob DescriptionJ...\n117    Systèmes de faisceaux de câbles modernes et in...\n118    Job Description - Lead Expert Supplier Quality...\n119    Vantive: A New Company Built On Our LegacyBaxt...\nName: job_description, dtype: object",
#  '120                                                  NaN\n121                                                  NaN\n122                                                  NaN\n123                                                  NaN\n124                                                  NaN\n125                                                  NaN\n126                                                  NaN\n127                                                  NaN\n128                                                  NaN\n129    Job DescriptionCartographier les processus de ...\n130    An exciting opportunity to work within a vibra...\n131    An exciting opportunity to work within a vibra...\nName: job_description, dtype: object',
#  "132    Job Name: Tunisia - Asa:01 Pre-Shipment & Load...\n133    Job SummaryYou will be responsible for selling...\n134    Dans le cadre d’une monte en charge et renforc...\n135    About Four Seasons:Four Seasons is powered by ...\n136    An exciting opportunity to work within a vibra...\n137    Job DescriptionEffectuer la maintenance curati...\n138    Job DescriptionAssurer la disponibilité des mo...\n139    Regulatory Affairs Officer 295004-placeholder ...\n140    Systèmes de faisceaux de câbles modernes et in...\n141    Job Title: \xa0Financial Accountant  Location: Tu...\n142    Description de l'entrepriseLe Groupe LACROIX (...\n143    Vantive: A New Company Built On Our LegacyBaxt...\nName: job_description, dtype: object"]

# %%
bayt_skills = []

for i in tqdm(bat, desc="Extracting skills"):
    s = skills_extraction(i)
    bayt_skills.append(s)
# Out:
# Extracting skills: 100%|██████████| 12/12 [00:11<00:00,  1.08it/s]

# %%
len(bayt_skills)
# Out:
# 12

# %%
bs = []
for i in bayt_skills:
    for j in i:
        bs.append(j)

# %%
len(bs)
# Out:
# 121

# %%
bayt_skills = pd.DataFrame(bs, columns=['skills'])

# %%
bayt_skills.to_csv('bayt_skills.csv', index=False)

# %%
total_skills = pd.concat([linkedin_skills, bayt_skills])

# %%
total_skills.to_csv('total_skills.csv', index=False)

# %% [markdown]
# ## Skills & Titles Translation

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("translation", model="Helsinki-NLP/opus-mt-mul-en")

# %%
h = pipe("comos estas" )

# %%
total_skills.skills = total_skills.skills.apply(lambda x: pipe(x)[0]['translation_text'])

# %%
total_skills
# Out:
#                    skills
# 0               12th year
# 1        customer service
# 2           communication
# 3      hourly flexibility
# 4              leg by leg
# ..                    ...
# 116    Regulatory Affairs
# 117  Financial Accounting
# 118          Cable Makers
# 119          Availability
# 120  Valid arguments are:
#
# [810 rows x 1 columns]

# %%
total_skills.to_csv('total_skills.csv', index=False)

# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests
import pandas as pd
import tqdm
from requests_ip_rotator import ApiGateway

from fake_useragent import UserAgent
from itertools import cycle
import random 
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import csv
import time

import datetime
import re

from transformers import pipeline

import google.generativeai as genai

def convert_relative_date(relative_date_str):
    """Converts a relative date string (e.g., "1 year ago", "2 months ago") to an actual date."""
    relative_date_str = relative_date_str.replace("+", "").strip()
    
    match = re.match(r"(\d+) (\w+) ago", relative_date_str)
    if not match:
        return None

    amount, unit = int(match.group(1)), match.group(2)

    now = datetime.datetime.now()

    if unit == "year" or unit == "years":
        delta = datetime.timedelta(days=amount * 365)
    elif unit == "month" or unit == "months":
        delta = datetime.timedelta(days=amount * 30)  # Approximation
    elif unit == "day" or unit == "days":
        delta = datetime.timedelta(days=amount)
    elif unit == "hour" or unit == "hours":
        delta = datetime.timedelta(hours=amount)
    elif unit == "minute" or unit == "minutes":
        delta = datetime.timedelta(minutes=amount)
    elif unit == "second" or unit == "seconds":
        delta = datetime.timedelta(seconds=amount)
    elif unit == "week" or unit == "weeks":
        delta = datetime.timedelta(weeks=amount)
    
    else:
        return None

    actual_date = now - delta
    return actual_date.strftime("%Y-%m")




def scrape_linkedin_links() -> pd.DataFrame:
    
    url = "https://www.linkedin.com/jobs/search?location=Tunisia&geoId=102134353&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0&currentJobId=3796559592"
    service = Service(ChromeDriverManager().install())  
    driver = webdriver.Chrome(service=service)
    driver.get(url)
  



    df = pd.DataFrame(columns=['links'])

    while True:
        global links
        global df1
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)

        links = driver.find_elements(By.CSS_SELECTOR,".base-card__full-link.absolute.top-0.right-0.bottom-0.left-0.p-0")
        l = [link.get_attribute('href') for link in links]
        df1 = pd.DataFrame(l, columns=['links'])
       

            
        try:
            
            more = driver.find_element(By.CSS_SELECTOR,".infinite-scroller__show-more-button.infinite-scroller__show-more-button--visible")
        
            if more:
                time.sleep(2)
                more.click()
    


            
        except:
            continue
        
        if len(df1) == len(df):
            continue
        else:
            df = pd.concat([df,df1],axis=0,ignore_index=True)

        if len(df) >= 400:
            break
            
    return df



def scrape_bayt_links() -> pd.DataFrame:

    url = "https://www.bayt.com/en/tunisia/jobs/?page=1"

    service = Service(ChromeDriverManager().install())  
    driver = webdriver.Chrome(service=service)

    page = 1

    df = []

    while True:


        driver.get(url)
        time.sleep(2)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)

        link = driver.find_elements(By.CSS_SELECTOR,".col.u-stretch.t-large.m0")
        
        for l in link:
            df.append(l.find_element(By.TAG_NAME,"a").get_attribute('href'))

    
        
        page += 1
        
        url = f"https://www.bayt.com/en/tunisia/jobs/?page={page}"
        
        if page == 18:
            break

    dff = pd.DataFrame(df, columns=['links'])
    
    return dff




        


def scrape_linkedin_jobs_description(df: pd.DataFrame) -> pd.DataFrame:
    
    user = UserAgent()

    
    storage = []
    
    for u in tqdm.tqdm(df.links):
        headers =  {
            'User-Agent': user.random
        }

        url = u
        english_url = url.replace('tn.linkedin.com','www.linkedin.com') 
        
    
        try:
            request = requests.get(english_url, timeout=3600 , headers= headers)
        
        except Exception as e :
            print(e)
            continue
        
        if request.status_code != 200:
    

            continue
        
            
        soup = BeautifulSoup(request.text, 'html.parser')
        time.sleep(3)
        
        job_title = soup.find('h1', {'class': 'top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title'})
        job_description = soup.find('div', {'class': 'show-more-less-html__markup show-more-less-html__markup--clamp-after-5 relative overflow-hidden'})
        company = soup.find('a', {'class': 'topcard__org-name-link topcard__flavor--black-link'})
        location = soup.find('span', {'class': 'topcard__flavor topcard__flavor--bullet'})
        post_date = soup.find('span', {'class': 'posted-time-ago__text topcard__flavor--metadata'})


        
        criteria = soup.find_all('span', {'class': 'description__job-criteria-text description__job-criteria-text--criteria'})
    
    
        
        storage.append({'post_date': convert_relative_date(post_date.text.strip()) if post_date else None,
                        'job_title':job_title.text.strip() if job_title else None, 
                        'job_description':job_description.text.strip() if job_description else None, 
                        'company':company.text.strip() if company else None,
                        'location':location.text.strip() if location else None, 
                        'seniority': criteria[0].text.strip() if criteria and len(criteria) > 0 else None,
                        'employement_type': criteria[1].text.strip() if criteria and len(criteria) > 1 else None,
                        'job_functions': criteria[2].text.strip() if criteria and len(criteria) > 2 else None,
                        'industry': criteria[3].text.strip() if criteria and len(criteria) > 3 else None,
                        
                        })
    dff = pd.DataFrame(storage, columns=['post_date','job_title','job_description','company','location','seniority','employement_type','job_functions','industry'])
    
    return dff
    


def scrape_bayt_jobs_description(df: pd.DataFrame) -> pd.DataFrame:
    user = UserAgent()


    storage = pd.DataFrame(columns=['post_date','job_title','job_description','company','location'])


    for u in tqdm.tqdm(df.links):
        headers =  {
            'User-Agent': user.random
        }

        url = u
        
    
        try:
            request = requests.get(url, timeout=3600 , headers= headers)
        
        except Exception as e :
            print(e)
            continue
        
        if request.status_code != 200:
            continue
        
            
        soup = BeautifulSoup(request.text, 'html.parser')
        time.sleep(2)
        
        post_date = soup.find('div', {'class': 't-small t-mute m10b'})
        
        job_title = soup.find('h1', {'class': 'h3 t-break'})

        job_description = soup.find('div', {'class': 't-break'})

        company = soup.find('a', {'class': 'is-black t-bold'})

        location = soup.find('span', {'class': 't-mute'})
        


        
        criteria = soup.find_all('dl', {'class': 'dlist is-spaced is-fitted t-small'})
        
        
        
    
    
    
        
        a = pd.DataFrame({'post_date':convert_relative_date(post_date.text.strip().split('\n')[0]) if post_date else None,
                        'job_title':job_title.text.strip() if job_title else None, 
                        'job_description':job_description.text.strip() if job_description else None, 
                        'company':company.text.strip() if company else None,
                        'location':location.text.strip() if location else None, 
                        'industry': criteria[0].text.strip().split('\n')[5] if criteria else None,
    
                        
                        } , index=[0])

        

        storage = pd.concat([storage,a] ,axis=0)

    return storage


        


def skills_extraction(job_desc):
    prompt_empy = '{"key_words":[]}'

    prompt = '''
    Read the following job description and return key words of all the skills required for this job.

    No explanations, uniques keywords, no duplicates, Be breif.

    '''
    
    genai.configure(api_key="AIzaSyAX5hRxjQ64IqZxqNcdj7ONpALMWxnIHb0")

    model = genai.GenerativeModel('gemini-1.5-flash')
    
    if job_desc == "":
        prompt_id = prompt_empy
    else:
        prompt_id = prompt + job_desc
    output = model.generate_content(prompt_id)

    
    return output.candidates[0].content.parts[0].text.strip().replace("-","").split('\n')





def get_skills(df: pd.DataFrame) -> pd.DataFrame:
    
    description = df.job_description
    
    batch_size = len(description) // 12
    
    batches = np.array_split(description, batch_size)

    # Access individual batches
    batchs = [batches[0], batches[1], batches[2], batches[3], batches[4], batches[5], batches[6], batches[7], batches[8], batches[9], batches[10], batches[11]]
    
    
    bat = []

    for i in batchs:
        b= ""
        for j in i:
            b = b + j
        bat.append(b)
    
    
    
    ln_skills = []

    for i in tqdm(bat, desc="Extracting skills"):
        s = skills_extraction(i)
        ln_skills.append(s)
        
        
    ls = []
    for i in ln_skills:
        for j in i:
            ls.append(j)


    return pd.DataFrame(ls, columns=['skills'])




Translator = pipeline("translation", model="Helsinki-NLP/opus-mt-mul-en")





def main():
    

        
        
    ln_links = scrape_linkedin_links()
    
    bayt_links = scrape_bayt_links()
    
    
    ln_jobs = scrape_linkedin_jobs_description(ln_links)
    
    bayt_jobs = scrape_bayt_jobs_description(bayt_links)
    
    
    ln_skills = get_skills(ln_jobs)
    
    print('waiting for 1 min')
    time.sleep(60)
    
    bayt_skills = get_skills(bayt_jobs)
    
    
    total_skills = pd.concat([ln_skills, bayt_skills])

    
    total_skills_english = total_skills.skills.apply(lambda x: Translator(x)[0]['translation_text'])
    
    ln_jobs.job_title = ln_jobs.job_title.apply(lambda x: Translator(x)[0]['translation_text'])
    
    bayt_jobs.job_title = bayt_jobs.job_title.apply(lambda x: Translator(x)[0]['translation_text'])
    
    
    
    ln_jobs.to_csv('lntest27072024.csv',index=False)
    
    bayt_jobs.to_csv('bayttest27072024.csv',index=False)
    
    total_skills_english.to_csv('total_skills_test27072024.csv',index=False)

# %%
import pandas as pd


df = pd.read_csv('lntest27072024.csv')


df.post_date = pd.to_datetime(df.post_date, format="%Y-%m")

# %%
df.post_date
# Out:
# 0     2024-01-01
# 1     2024-07-01
# 2     2023-07-01
# 3     2024-07-01
# 4     2024-07-01
#          ...
# 296   2023-11-01
# 297   2024-07-01
# 298   2023-07-01
# 299   2024-07-01
# 300   2024-07-01
# Name: post_date, Length: 301, dtype: datetime64[ns]

# %%
from pyresparser import ResumeParser

def process_plain_text(text):

  data = ResumeParser(text)
  return data

doc = open("skills.txt", "r").read()


p = process_plain_text(doc)
p
# Out:
# c:\Users\nki\Documents\Steven Jobs\venv\Lib\site-packages\spacy\util.py:918: UserWarning: [W094] Model 'en_training' (0.0.0) specifies an under-constrained spaCy version requirement: >=2.1.4. This can lead to compatibility problems with older versions, or as new spaCy versions are released, because the model may say it's compatible when it's not. Consider changing the "spacy_version" in your meta.json to a version range, with a lower and upper pin. For example: >=3.7.5,<3.8.0
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 11
#       6   return data
#       8 doc = open("skills.txt", "r").read()
# ---> 11 p = process_plain_text(doc)
#      12 p
#
# Cell In[8], line 5, in process_plain_text(text)
#       3 def process_plain_text(text):
# ----> 5   data = ResumeParser(text)
#       6   return data
#
# File c:\Users\nki\Documents\Steven Jobs\venv\Lib\site-packages\pyresparser\resume_parser.py:21, in ResumeParser.__init__(self, resume, skills_file, custom_regex)
#      14 def __init__(
#      15     self,
#      16     resume,
#      17     skills_file=None,
#      18     custom_regex=None
#      19 ):
#      20     nlp = spacy.load('en_core_web_sm')
# ---> 21     custom_nlp = spacy.load(os.path.dirname(os.path.abspath(__file__)))
#      22     self.__skills_file = skills_file
#      23     self.__custom_regex = custom_regex
#
# File c:\Users\nki\Documents\Steven Jobs\venv\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File c:\Users\nki\Documents\Steven Jobs\venv\Lib\site-packages\spacy\util.py:467, in load_model(name, vocab, disable, enable, exclude, config)
#     465         return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     466     if Path(name).exists():  # path to model data directory
# --> 467         return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#     468 elif hasattr(name, "exists"):  # Path or Path-like to model data
#     469     return load_model_from_path(name, **kwargs)  # type: ignore[arg-type]
#
# File c:\Users\nki\Documents\Steven Jobs\venv\Lib\site-packages\spacy\util.py:538, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     536 config_path = model_path / "config.cfg"
#     537 overrides = dict_to_dot(config, for_overrides=True)
# --> 538 config = load_config(config_path, overrides=overrides)
#     539 nlp = load_model_from_config(
#     540     config,
#     541     vocab=vocab,
#    (...)
#     545     meta=meta,
#     546 )
#     547 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File c:\Users\nki\Documents\Steven Jobs\venv\Lib\site-packages\spacy\util.py:714, in load_config(path, overrides, interpolate)
#     712 else:
#     713     if not config_path or not config_path.is_file():
# --> 714         raise IOError(Errors.E053.format(path=config_path, name="config file"))
#     715     return config.from_disk(
#     716         config_path, overrides=overrides, interpolate=interpolate
#     717     )
#
# OSError: [E053] Could not read config file from c:\Users\nki\Documents\Steven Jobs\venv\Lib\site-packages\pyresparser\config.cfg

# %%
from transformers import pipeline

Translator = pipeline("translation", model="Helsinki-NLP/opus-mt-mul-en", max_length=20000000000)

# %%
Translator('we')[0]['translation_text']
# Out:
# 'we'

# %%
import pandas as pd


ln = pd.read_csv(r'C:\Users\nki\Documents\Steven Jobs\lntest27072024.csv')
bayt = pd.read_csv(r'C:\Users\nki\Documents\Steven Jobs\bayttest27072024.csv')

# %%
jobs = pd.concat([ln, bayt], axis=0)

# %%
jobs
# Out:
#      post_date                                          job_title  \
# 0   2024-07-01                                    Receipt (H/F/X)
# 1   2024-07-01         Financial Assistant(s) (Online, Full Time)
# 2   2024-07-01                              Guest Service Manager
# 3   2024-07-01  Call for Independent Administrators' candidacy...
# 4   2023-07-01                      Job notice: Copy (M/F) - Beja
# ..         ...                                                ...
# 15  2024-07-01                        HO Quality Operations Plant
# 16         NaN                          Assistant running manager
# 17  2024-07-01                               Representative rooms
# 18  2024-07-01                Merchandising Coordinator - Apparel
# 19  2024-07-01            Customer Care Advisor - Spanish Speaker
#
#                                       job_description  \
# 0   Description de l'entreprisePourquoi travailler...
# 1   Entreprise : AzurreoLieu : À Distance (télétra...
# 2   Description de l'entreprisePourquoi travailler...
# 3   Description de l'entrepriseStartup Tunisia est...
# 4   Anúncio de emprego: Copeiro (M/F) - Beja:SERLI...
# ..                                                ...
# 15  LEONI is a global provider of products, soluti...
# 16  Assistant stewarding manager page is loaded As...
# 17  Job Description:At Ferring Pharmaceuticals, we...
# 18  Job Title:  Merchandising Coordinator, Apparel...
# 19  Oferta de trabajo:  Inbound Customer Care Agen...
#
#                             company                      location  \
# 0        Mövenpick Hotels & Resorts         Tunis, Tunis, Tunisia
# 1                           Azurreo                       Tunisia
# 2        Mövenpick Hotels & Resorts         Tunis, Tunis, Tunisia
# 3                     Smart Capital  Ḥalq al-Wādī, Tunis, Tunisia
# 4                     Grupo Serlima           Béja, Béja, Tunisia
# ..                              ...                           ...
# 15                         Leoni AG               Sousse, Tunisia
# 16  Four Seasons Hotels and Resorts                Tunis, Tunisia
# 17                     Ferring B.V.                       Tunisia
# 18                     National Pen                Tunis, Tunisia
# 19                     National Pen                Tunis, Tunisia
#
#          seniority employement_type                 job_functions  \
# 0   Not Applicable        Full-time                Administrative
# 1      Entry level        Full-time                       Finance
# 2   Not Applicable        Full-time                         Other
# 3        Executive        Full-time                         Other
# 4      Entry level        Full-time  Management and Manufacturing
# ..             ...              ...                           ...
# 15             NaN              NaN                           NaN
# 16             NaN              NaN                           NaN
# 17             NaN              NaN                           NaN
# 18             NaN              NaN                           NaN
# 19             NaN              NaN                           NaN
#
#                            industry
# 0                       Hospitality
# 1                Telecommunications
# 2                       Hospitality
# 3                Financial Services
# 4               Facilities Services
# ..                              ...
# 15  Other Business Support Services
# 16  Other Business Support Services
# 17  Other Business Support Services
# 18  Other Business Support Services
# 19  Other Business Support Services
#
# [108 rows x 9 columns]
